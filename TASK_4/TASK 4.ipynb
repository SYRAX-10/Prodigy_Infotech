# %%
#loading importarnt libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#load the csv file 

df=pd.read_csv(r"C:\Users\sohan\OneDrive\Desktop\New folder\New folder (5)\RTA Dataset.csv")
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.describe(include='all')
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count      12316       12316              12316         12316
# unique      1074           7                  5             3
# top     15:30:00      Friday              18-30          Male
# freq         120        2041               4271         11437
# mean         NaN         NaN                NaN           NaN
# std          NaN         NaN                NaN           NaN
# min          NaN         NaN                NaN           NaN
# 25%          NaN         NaN                NaN           NaN
# 50%          NaN         NaN                NaN           NaN
# 75%          NaN         NaN                NaN           NaN
# max          NaN         NaN                NaN           NaN
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                11575                   11737              11487
# unique                   7                       4                  7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
#EXPLORATORY DATA ANALYSIS

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Distribution of Accident Severity

df["Accident_severity"].value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
#plotting the distribution of accident severity

sns.countplot(x=df["Accident_severity"])
plt.title("Distribution of Accident Severity")
plt.show()

# %%
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
#dropping columns which have more than 25% missing values

df.drop(['Service_year_of_vehicle','Defect_of_vehicle','Fitness_of_casuality'], axis=1, inplace=True)
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Area_accident_occured  ... Number_of_casualties  \
# ...

# %%
#Storing categorical column name to a new variable

categorical = [i for i in df.columns if df[i].dtype == object]

print("The categorical columns are: ",categorical)
# Out:
# The categorical columns are:  ['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality', 'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity']

# %%
#for categorical values we can replace the null values with the mode of it

for i in categorical:
    df[i].fillna(df[i].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# Pedestrian_movement            0
# Cause_of_accident              0
# ...

# %%
#for categorical values we can replace the null values with the mode of it
for i in categorical:
    df[i].fillna(df[i].mode()[0],inplace = True)

# %%
#cheking for null values 

df.isna().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# Pedestrian_movement            0
# Cause_of_accident              0
# ...

# %%
#plotting raltionship between Number_of_casualities 

sns.scatterplot(x=df["Number_of_casualties"],y=df["Number_of_vehicles_involved"],hue=df["Accident_severity"])
# Out:
# <Axes: xlabel='Number_of_casualties', ylabel='Number_of_vehicles_involved'>

# %%
#join plot 

sns.jointplot(x=df["Number_of_casualties"],y=df["Number_of_vehicles_involved"],hue=df["Accident_severity"])

# %%
#checking the correlation between numerical columns

numeric_df = df.select_dtypes(include=[np.number])
numeric_df.corr()
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
#plotting the correlation using heat map

sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %%
#storing numerical column names to a variable

numerical = [i for i in numeric_df.columns if df[i].dtype!='object']
print("The numerical columns are: ",numerical)
# Out:
# The numerical columns are:  ['Number_of_vehicles_involved', 'Number_of_casualties']

# %%
#Distribution of numerical columns

plt.figure(figsize=(10,10))
plotnumber = 1

for i in numerical:
    if plotnumber<=numeric_df.shape[1]:
        ax1= plt.subplot(2,2,plotnumber)
        plt.hist(df[i],color='green')
        plt.xticks(fontsize=10)
        plt.yticks(fontsize=10)
        plt.title("Frequency distribution of\n"+str(i),fontsize=15)
    plotnumber+=1

# %%
#count plot for categorical values

plt.figure(figsize=(10,200))
plotnumber = 1

for col in categorical:
    if plotnumber <= len(categorical) and col!="Pedestrian_movement":
        ax1 = plt.subplot(28,1,plotnumber)  
        sns.countplot(data=df, y=col, palette='magma')
        plt.xticks(fontsize=10)
        plt.yticks(fontsize=10)
        plt.title("Count of\n"+str(col.title()),fontsize=15)
        plt.xlabel("")
        plt.ylabel("")
    plotnumber +=1

# %%
#handling categorical values

df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# ...

# %%
#importing label encoder module

from pandas import DataFrame
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

#applying label encoder to categorical values

df1 = DataFrame()

#adding all the categorical columns except the output to data frame

for i in categorical:
    if i!="Accident_severity":
        df1[i] = le.fit_transform(df[i])

# %%
#confrirming the changes

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Time                     12316 non-null  int64
#  1   Day_of_week              12316 non-null  int64
#  2   Age_band_of_driver       12316 non-null  int64
#  3   Sex_of_driver            12316 non-null  int64
#  4   Educational_level        12316 non-null  int64
#  5   Vehicle_driver_relation  12316 non-null  int64
#  6   Driving_experience       12316 non-null  int64
#  7   Type_of_vehicle          12316 non-null  int64
#  8   Owner_of_vehicle         12316 non-null  int64
#  9   Area_accident_occured    12316 non-null  int64
#  10  Lanes_or_Medians         12316 non-null  int64
#  11  Road_allignment          12316 non-null  int64
#  12  Types_of_Junction        12316 non-null  int64
#  13  Road_surface_type        12316 non-null  int64
# ...

# %%
plt.figure(figsize=(25,25))
sns.set(font_scale=1)
sns.heatmap(df1.corr(),annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df1.head()
# Out:
#    Time  Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0   420            1                   0              1                  0
# 1   420            1                   1              1                  4
# 2   420            1                   0              1                  4
# 3   594            3                   0              1                  4
# 4   594            3                   0              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                0
# 1                        0                   3               11
# 2                        0                   0                5
# 3                        0                   2               11
# 4                        0                   1                0
#
#    Owner_of_vehicle  Area_accident_occured  ...  Weather_conditions  \
# ...

# %%
#import chi2 test

from sklearn.feature_selection import chi2
f_p_values = chi2(df1,df["Accident_severity"])

# %%
f_p_values
# Out:
# (array([6.92221439e+02, 1.58220709e-01, 8.91539214e+00, 1.43189401e-01,
#         1.74584765e-01, 5.34534549e+00, 4.49967858e+00, 1.07767124e+00,
#         1.10426215e+00, 3.61654037e+00, 3.28161464e+00, 1.31930601e-01,
#         3.08648691e+00, 6.99480557e+00, 6.15103078e-01, 1.60828236e+01,
#         1.14934538e+00, 1.00963228e+01, 2.20071197e+00, 3.21686020e+00,
#         1.25944789e-01, 1.37784134e+01, 2.02737881e-01, 1.25914306e+00,
#         3.97479818e-01, 3.19366551e+00]),
#  array([4.85315862e-151, 9.23937958e-001, 1.15890328e-002, 9.30908116e-001,
#         9.16409114e-001, 6.90673790e-002, 1.05416165e-001, 5.83427189e-001,
#         5.75721597e-001, 1.63937473e-001, 1.93823502e-001, 9.36163348e-001,
#         2.13686893e-001, 3.02759144e-002, 7.35244973e-001, 3.21854237e-004,
#         5.62889079e-001, 6.42112839e-003, 3.32752607e-001, 2.00201664e-001,
#         9.38969394e-001, 1.01872169e-003, 9.03599597e-001, 5.32820049e-001,
# ...

# %%
#for better understanding we can convert the p values to data frame

f_p_values1 = pd.DataFrame({"Features": df1.columns, "Fscore": f_p_values[0], "p_values": f_p_values[1]})
f_p_values1
# Out:
#                    Features      Fscore       p_values
# 0                      Time  692.221439  4.853159e-151
# 1               Day_of_week    0.158221   9.239380e-01
# 2        Age_band_of_driver    8.915392   1.158903e-02
# 3             Sex_of_driver    0.143189   9.309081e-01
# 4         Educational_level    0.174585   9.164091e-01
# 5   Vehicle_driver_relation    5.345345   6.906738e-02
# 6        Driving_experience    4.499679   1.054162e-01
# 7           Type_of_vehicle    1.077671   5.834272e-01
# 8          Owner_of_vehicle    1.104262   5.757216e-01
# 9     Area_accident_occured    3.616540   1.639375e-01
# 10         Lanes_or_Medians    3.281615   1.938235e-01
# 11          Road_allignment    0.131931   9.361633e-01
# 12        Types_of_Junction    3.086487   2.136869e-01
# 13        Road_surface_type    6.994806   3.027591e-02
# 14  Road_surface_conditions    0.615103   7.352450e-01
# 15         Light_conditions   16.082824   3.218542e-04
# ...

# %%
#since we want lower Pvalues we are sorting the features

f_p_values1.sort_values(by="p_values", ascending=True)
# Out:
#                    Features      Fscore       p_values
# 0                      Time  692.221439  4.853159e-151
# 15         Light_conditions   16.082824   3.218542e-04
# 21     Age_band_of_casualty   13.778413   1.018722e-03
# 17        Type_of_collision   10.096323   6.421128e-03
# 2        Age_band_of_driver    8.915392   1.158903e-02
# 13        Road_surface_type    6.994806   3.027591e-02
# 5   Vehicle_driver_relation    5.345345   6.906738e-02
# 6        Driving_experience    4.499679   1.054162e-01
# 9     Area_accident_occured    3.616540   1.639375e-01
# 10         Lanes_or_Medians    3.281615   1.938235e-01
# 19           Casualty_class    3.216860   2.002017e-01
# 25        Cause_of_accident    3.193666   2.025370e-01
# 12        Types_of_Junction    3.086487   2.136869e-01
# 18         Vehicle_movement    2.200712   3.327526e-01
# 23        Work_of_casuality    1.259143   5.328200e-01
# 16       Weather_conditions    1.149345   5.628891e-01
# ...

# %%
#after evaluating we are removing the columns which are not important


df2=df.drop(['Owner_of_vehicle','Type_of_vehicle','Road_surface_conditions','Pedestrian_movement','Casualty_severity','Educational_level','Day_of_week','Sex_of_driver','Road_allignment','Sex_of_casualty'],axis=1) 
df2.head()
# Out:
#        Time Age_band_of_driver Vehicle_driver_relation Driving_experience  \
# 0  17:02:00              18-30                Employee              1-2yr
# 1  17:02:00              31-50                Employee         Above 10yr
# 2  17:02:00              18-30                Employee              1-2yr
# 3   1:06:00              18-30                Employee             5-10yr
# 4   1:06:00              18-30                Employee              2-5yr
#
#   Area_accident_occured                                  Lanes_or_Medians  \
# 0     Residential areas  Two-way (divided with broken lines road marking)
# 1          Office areas                                 Undivided Two way
# 2    Recreational areas                                             other
# 3          Office areas                                             other
# 4      Industrial areas                                             other
#
#   Types_of_Junction Road_surface_type       Light_conditions  \
# ...

# %%
df2.shape
# Out:
# (12316, 19)

# %%
#to check distinct values in each categorical column

categorical_new = [i for i in df2.columns if df2[i].dtypes == "object"]
print(categorical_new)
# Out:
# ['Time', 'Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience', 'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty', 'Work_of_casuality', 'Cause_of_accident', 'Accident_severity']

# %%
for i in categorical_new:
    print(df2[i].value_counts())
# Out:
# Time
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 0:52:00       1
# 4:49:00       1
# 14:31:00      1
# 19:18:00      1
# 2:47:00       1
# Name: count, Length: 1074, dtype: int64
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64
# Vehicle_driver_relation
# Employee    10206
# Owner        1973
# Other         123
# Unknown        14
# Name: count, dtype: int64
# Driving_experience
# 5-10yr        4192
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# No Licence     118
# unknown         33
# Name: count, dtype: int64
# Area_accident_occured
# Other                              4058
# Office areas                       3451
# Residential areas                  2060
#  Church areas                      1060
#  Industrial areas                   456
# School areas                        415
# ...

# %%
#get dummy 

dummy = pd.get_dummies(df2[['Age_band_of_driver','Vehicle_driver_relation', 'Driving_experience','Area_accident_occured', 'Lanes_or_Medians','Types_of_Junction', 'Road_surface_type','Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class','Age_band_of_casualty','Cause_of_accident']])
dummy.head()
# Out:
#    Age_band_of_driver_18-30  Age_band_of_driver_31-50  \
# 0                      True                     False
# 1                     False                      True
# 2                      True                     False
# 3                      True                     False
# 4                      True                     False
#
#    Age_band_of_driver_Over 51  Age_band_of_driver_Under 18  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    Age_band_of_driver_Unknown  Vehicle_driver_relation_Employee  \
# 0                       False                              True
# 1                       False                              True
# 2                       False                              True
# ...

# %%
#concatinate dummy and old data frame 

df3 = pd.concat([df2,dummy],axis=1)
df3.head()
# Out:
#        Time Age_band_of_driver Vehicle_driver_relation Driving_experience  \
# 0  17:02:00              18-30                Employee              1-2yr
# 1  17:02:00              31-50                Employee         Above 10yr
# 2  17:02:00              18-30                Employee              1-2yr
# 3   1:06:00              18-30                Employee             5-10yr
# 4   1:06:00              18-30                Employee              2-5yr
#
#   Area_accident_occured                                  Lanes_or_Medians  \
# 0     Residential areas  Two-way (divided with broken lines road marking)
# 1          Office areas                                 Undivided Two way
# 2    Recreational areas                                             other
# 3          Office areas                                             other
# 4      Industrial areas                                             other
#
#   Types_of_Junction Road_surface_type       Light_conditions  \
# ...

# %%
#seperating independent and dependent 

df3.drop(['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience', 'Area_accident_occured', 'Lanes_or_Medians','Types_of_Junction', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Type_of_collision',
'Vehicle_movement','Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident'], axis=1, inplace=True)

df3.head()
# Out:
#        Time  Number_of_vehicles_involved  Number_of_casualties  \
# 0  17:02:00                            2                     2
# 1  17:02:00                            2                     2
# 2  17:02:00                            2                     2
# 3   1:06:00                            2                     2
# 4   1:06:00                            2                     2
#
#   Work_of_casuality Accident_severity  Age_band_of_driver_18-30  \
# 0            Driver     Slight Injury                      True
# 1            Driver     Slight Injury                     False
# 2            Driver    Serious Injury                      True
# 3            Driver     Slight Injury                      True
# 4            Driver     Slight Injury                      True
#
#    Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 0                     False                       False
# 1                      True                       False
# ...

# %%
x = df3.drop(["Accident_severity"],axis=1)
x.shape
# Out:
# (12316, 120)

# %%
y= df3.iloc[:,4]
y.head()
# Out:
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury
# Name: Accident_severity, dtype: object

# %%
y.value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
#plotting count plot using seaborn

sns.countplot(x=y, palette = 'muted')
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
# Convert 'Time' column to numerical format
x['Time'] = pd.to_datetime(x['Time']).dt.hour + pd.to_datetime(x['Time']).dt.minute / 60

# Convert categorical columns to numerical values
categorical_columns = x.select_dtypes(include=['object']).columns
x[categorical_columns] = x[categorical_columns].apply(lambda col: le.fit_transform(col))

# Oversampling 
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
xo, yo = oversample.fit_resample(x, y)

# %%
#checking the oversampling output 

y1 = pd.DataFrame(yo)
y1.value_counts()
# Out:
# Accident_severity
# Fatal injury         10415
# Serious Injury       10415
# Slight Injury        10415
# Name: count, dtype: int64

# %%
sns.countplot(x =yo, palette = 'muted')
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
#splitting the data

from sklearn.model_selection import train_test_split

#splitting 70% of the data to training data and 30% of data to testing data 

x_train,x_test,y_train,y_test = train_test_split(xo,yo,test_size=0.30,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (21871, 120) (9374, 120) (21871,) (9374,)

# %%
#KNN Model Creation

from sklearn.neighbors import KNeighborsClassifier

model_KNN= KNeighborsClassifier(n_neighbors=5)
model_KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model_KNN.predict(x_test)

# %%
y_pred
# Out:
# array(['Serious Injury', 'Slight Injury', 'Slight Injury', ...,
#        'Fatal injury', 'Serious Injury', 'Slight Injury'],
#       shape=(9374,), dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
report_KNN = classification_report(y_test,y_pred)
print(report_KNN)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.99      1.00      1.00      3126
# Serious Injury       0.92      0.98      0.95      3144
#  Slight Injury       0.98      0.91      0.94      3104
#
#       accuracy                           0.96      9374
#      macro avg       0.97      0.96      0.96      9374
#   weighted avg       0.97      0.96      0.96      9374

# %%
accuracy_KNN = accuracy_score(y_test,y_pred)
print(accuracy_KNN)
# Out:
# 0.96436953275016

# %%
#Confuion Matrix

matrix_KNN = confusion_matrix(y_test,y_pred)
print(matrix_KNN,'\n')
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
# [[3125    1    0]
#  [   3 3084   57]
#  [  20  253 2831]]
#
# ...
